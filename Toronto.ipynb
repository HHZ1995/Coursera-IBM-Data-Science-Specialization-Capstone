# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\huanz\anaconda3\lib\site-packages (4.6.3)

# %%
# !pip install lxml
# Out:
# Requirement already satisfied: lxml in c:\users\huanz\anaconda3\lib\site-packages (4.2.5)

# %%
# !pip install html5lib
# Out:
# Requirement already satisfied: html5lib in c:\users\huanz\anaconda3\lib\site-packages (1.0.1)
# Requirement already satisfied: six>=1.9 in c:\users\huanz\anaconda3\lib\site-packages (from html5lib) (1.12.0)
# Requirement already satisfied: webencodings in c:\users\huanz\anaconda3\lib\site-packages (from html5lib) (0.5.1)

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\huanz\anaconda3\lib\site-packages (2.21.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\huanz\anaconda3\lib\site-packages (from requests) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\huanz\anaconda3\lib\site-packages (from requests) (2018.11.29)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\huanz\anaconda3\lib\site-packages (from requests) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\huanz\anaconda3\lib\site-packages (from requests) (1.24.1)

# %%
from bs4 import BeautifulSoup
import requests

# %%
import numpy as np

# %%
import pandas as pd

column_names = ['Postcode','Borough','Neighborhood']
neighborhoods = pd.DataFrame(columns = column_names)
neighborhoods
# Out:
# Empty DataFrame
# Columns: [Postcode, Borough, Neighborhood]
# Index: []

# %%
source = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
page = BeautifulSoup(source, 'lxml')
toronto_table = page.table.tbody

for distinct in toronto_table.find_all('tr')[1:]:
    
    postcode = distinct.find_all('td')[0].text
    
    try:
        borough = distinct.find_all('td')[1].a.text
        
    except:
        borough = distinct.find_all('td')[1].text
    
    try:
        neighborhood = distinct.find_all('td')[2].a.text
    except:
        neighborhood = borough
    
    neighborhoods = neighborhoods.append({'Postcode': postcode,
                                          'Borough': borough,
                                          'Neighborhood': neighborhood}, ignore_index = True)
    
neighborhoods.head()
# Out:
#   Postcode           Borough      Neighborhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %%
toronto_data = pd.DataFrame(neighborhoods)

# %%
toronto_data.drop_duplicates(['Borough','Neighborhood'], inplace = True)

# %%
toronto_data.replace('Not assigned', np.nan, inplace = True)
toronto_data.dropna(inplace = True)

# %%
toronto_data = toronto_data.groupby(['Postcode','Borough']).aggregate(lambda x: ','.join(x)).reset_index()
toronto_data
# Out:
#    Postcode           Borough  \
# 0       M1B       Scarborough
# 1       M1C       Scarborough
# 2       M1E       Scarborough
# 3       M1G       Scarborough
# 4       M1J       Scarborough
# 5       M1K       Scarborough
# 6       M1L       Scarborough
# 7       M1M       Scarborough
# 8       M1N       Scarborough
# 9       M1P       Scarborough
# 10      M1R       Scarborough
# 11      M1S       Scarborough
# 12      M1T       Scarborough
# 13      M1V       Scarborough
# 14      M1X       Scarborough
# 15      M2H        North York
# 16      M2J        North York
# 17      M2K        North York
# 18      M2L        North York
# 19      M2M        North York
# 20      M2R        North York
# 21      M3A        North York
# 22      M3B        North York
# 23      M3C        North York
# 24      M3H        North York
# 25      M3J        North York
# 26      M3K        North York
# 27      M3L        North York
# 28      M4A        North York
# 29      M4B         East York
# ..      ...               ...
# 54      M5S  Downtown Toronto
# 55      M5T  Downtown Toronto
# 56      M5V  Downtown Toronto
# 57      M5X  Downtown Toronto
# 58      M6A        North York
# 59      M6C              York
# 60      M6E              York
# 61      M6H      West Toronto
# 62      M6J      West Toronto
# 63      M6K      West Toronto
# 64      M6L        North York
# 65      M6M              York
# 66      M6P      West Toronto
# 67      M6R      West Toronto
# 68      M6S      West Toronto
# 69      M7A      Queen's Park
# 70      M7R       Mississauga
# 71      M8V         Etobicoke
# 72      M8W         Etobicoke
# 73      M8X         Etobicoke
# 74      M8Y         Etobicoke
# 75      M8Z         Etobicoke
# 76      M9A         Etobicoke
# 77      M9B         Etobicoke
# 78      M9C         Etobicoke
# 79      M9L        North York
# 80      M9M        North York
# 81      M9N              York
# 82      M9R         Etobicoke
# 83      M9V         Etobicoke
#
#                                          Neighborhood
# 0                                       Rouge,Malvern
# 1                Highland Creek,Rouge Hill,Port Union
# 2                   Scarborough,Morningside,West Hill
# 3                                              Woburn
# 4                                 Scarborough Village
# 5                                Ionview,Kennedy Park
# 6                       Clairlea,Golden Mile,Oakridge
# 7                                Cliffcrest,Cliffside
# 8                                         Birch Cliff
# 9   Dorset Park,Scarborough Town Centre,Wexford He...
# 10                                   Maryvale,Wexford
# 11                                          Agincourt
# 12                                      Tam O'Shanter
# 13                           Agincourt North,Milliken
# 14                                        Upper Rouge
# 15                                  Hillcrest Village
# 16                                         Henry Farm
# 17                                    Bayview Village
# 18                                         York Mills
# 19                             Newtonbrook,Willowdale
# 20                                    Willowdale West
# 21                                          Parkwoods
# 22                                         North York
# 23                                    Flemingdon Park
# 24                      Bathurst Manor,Wilson Heights
# 25                     Northwood Park,York University
# 26                                        CFB Toronto
# 27                                     Downsview West
# 28                                   Victoria Village
# 29                     Woodbine Gardens,Parkview Hill
# ..                                                ...
# 54                              University of Toronto
# 55            Chinatown,Grange Park,Kensington Market
# 56  CN Tower,King and Spadina,Railway Lands,South ...
# 57              First Canadian Place,Underground city
# 58                    Lawrence Heights,Lawrence Manor
# 59                                 Humewood-Cedarvale
# 60                                               York
# 61                    Dovercourt Village,West Toronto
# 62                            Little Portugal,Trinity
# 63                  Exhibition Place,Parkdale Village
# 64                                          Downsview
# 65                Keelesdale,Mount Dennis,Silverthorn
# 66                                          High Park
# 67                              Parkdale,Roncesvalles
# 68                                  Runnymede,Swansea
# 69                                       Queen's Park
# 70                                        Mississauga
# 71                                        New Toronto
# 72                              Alderwood,Long Branch
# 73                                       The Kingsway
# 74  Humber Bay,Mimico NE,Old Mill South,The Queens...
# 75                       Mimico NW,The Queensway West
# 76                                   Islington Avenue
# 77  Etobicoke,Islington,Princess Gardens,West Dean...
# 78                                      Markland Wood
# 79                                      Humber Summit
# 80                                    Emery,Humberlea
# 81                                             Weston
# 82                                  Kingsview Village
# 83  Beaumond Heights,Jamestown,Mount Olive,Silvers...
#
# [84 rows x 3 columns]

# %%
toronto_data.shape
# Out:
# (84, 3)
